# %% [markdown]
# # Introduction

# %% [markdown]
# ## bash Terminal

# %% [raw]
# !bash
# %%bash
# %%sh
# !git

# %%
# !cat mnist.py
# Out:
# import argparse
# import json
# import logging
# import os
# import sagemaker_containers
# import sys
# import torch
# import torch.distributed as dist
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# import torch.utils.data
# import torch.utils.data.distributed
# from torchvision import datasets, transforms
#
# logger = logging.getLogger(__name__)
# logger.setLevel(logging.DEBUG)
# logger.addHandler(logging.StreamHandler(sys.stdout))
#
#
# # Based on https://github.com/pytorch/examples/blob/master/mnist/main.py
# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
#         self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
#         self.conv2_drop = nn.Dropout2d()
#         self.fc1 = nn.Linear(320, 50)
#         self.fc2 = nn.Linear(50, 10)
#
#     def forward(self, x):
#         x = F.relu(F.max_pool2d(self.conv1(x), 2))
#         x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
#         x = x.view(-1, 320)
#         x = F.relu(self.fc1(x))
#         x = F.dropout(x, training=self.training)
#         x = self.fc2(x)
#         return F.log_softmax(x, dim=1)
#
#
# def _get_train_data_loader(batch_size, training_dir, is_distributed, **kwargs):
#     logger.info("Get train data loader")
#     dataset = datasets.MNIST(training_dir, train=True, transform=transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize((0.1307,), (0.3081,))
#     ]))
#     train_sampler = torch.utils.data.distributed.DistributedSampler(dataset) if is_distributed else None
#     return torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_sampler is None,
#                                        sampler=train_sampler, **kwargs)
#
#
# def _get_test_data_loader(test_batch_size, training_dir, **kwargs):
#     logger.info("Get test data loader")
#     return torch.utils.data.DataLoader(
#         datasets.MNIST(training_dir, train=False, transform=transforms.Compose([
#             transforms.ToTensor(),
#             transforms.Normalize((0.1307,), (0.3081,))
#         ])),
#         batch_size=test_batch_size, shuffle=True, **kwargs)
#
#
# def _average_gradients(model):
#     # Gradient averaging.
#     size = float(dist.get_world_size())
#     for param in model.parameters():
#         dist.all_reduce(param.grad.data, op=dist.reduce_op.SUM)
#         param.grad.data /= size
#
#
# def train(args):
#     is_distributed = len(args.hosts) > 1 and args.backend is not None
#     logger.debug("Distributed training - {}".format(is_distributed))
#     use_cuda = args.num_gpus > 0
#     logger.debug("Number of gpus available - {}".format(args.num_gpus))
#     kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
#     device = torch.device("cuda" if use_cuda else "cpu")
#
#     if is_distributed:
#         # Initialize the distributed environment.
#         world_size = len(args.hosts)
#         os.environ['WORLD_SIZE'] = str(world_size)
#         host_rank = args.hosts.index(args.current_host)
#         os.environ['RANK'] = str(host_rank)
#         dist.init_process_group(backend=args.backend, rank=host_rank, world_size=world_size)
#         logger.info('Initialized the distributed environment: \'{}\' backend on {} nodes. '.format(
#             args.backend, dist.get_world_size()) + 'Current host rank is {}. Number of gpus: {}'.format(
#             dist.get_rank(), args.num_gpus))
#
#     # set the seed for generating random numbers
#     torch.manual_seed(args.seed)
#     if use_cuda:
#         torch.cuda.manual_seed(args.seed)
#
#     train_loader = _get_train_data_loader(args.batch_size, args.data_dir, is_distributed, **kwargs)
#     test_loader = _get_test_data_loader(args.test_batch_size, args.data_dir, **kwargs)
#
#     logger.debug("Processes {}/{} ({:.0f}%) of train data".format(
#         len(train_loader.sampler), len(train_loader.dataset),
#         100. * len(train_loader.sampler) / len(train_loader.dataset)
#     ))
#
#     logger.debug("Processes {}/{} ({:.0f}%) of test data".format(
#         len(test_loader.sampler), len(test_loader.dataset),
#         100. * len(test_loader.sampler) / len(test_loader.dataset)
#     ))
#
#     model = Net().to(device)
#     if is_distributed and use_cuda:
#         # multi-machine multi-gpu case
#         model = torch.nn.parallel.DistributedDataParallel(model)
#     else:
#         # single-machine multi-gpu case or single-machine or multi-machine cpu case
#         model = torch.nn.DataParallel(model)
#
#     optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)
#
#     for epoch in range(1, args.epochs + 1):
#         model.train()
#         for batch_idx, (data, target) in enumerate(train_loader, 1):
#             data, target = data.to(device), target.to(device)
#             optimizer.zero_grad()
#             output = model(data)
#             loss = F.nll_loss(output, target)
#             loss.backward()
#             if is_distributed and not use_cuda:
#                 # average gradients manually for multi-machine cpu case only
#                 _average_gradients(model)
#             optimizer.step()
#             if batch_idx % args.log_interval == 0:
#                 logger.info('Train Epoch: {} [{}/{} ({:.0f}%)] Loss: {:.6f}'.format(
#                     epoch, batch_idx * len(data), len(train_loader.sampler),
#                     100. * batch_idx / len(train_loader), loss.item()))
#         test(model, test_loader, device)
#     save_model(model, args.model_dir)
#
#
# def test(model, test_loader, device):
#     model.eval()
#     test_loss = 0
#     correct = 0
#     with torch.no_grad():
#         for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
#             output = model(data)
#             test_loss += F.nll_loss(output, target, size_average=False).item()  # sum up batch loss
#             pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
#             correct += pred.eq(target.view_as(pred)).sum().item()
#
#     test_loss /= len(test_loader.dataset)
#     logger.info('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
#         test_loss, correct, len(test_loader.dataset),
#         100. * correct / len(test_loader.dataset)))
#
#
# def model_fn(model_dir):
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     model = torch.nn.DataParallel(Net())
#     with open(os.path.join(model_dir, 'model.pth'), 'rb') as f:
#         model.load_state_dict(torch.load(f))
#     return model.to(device)
#
#
# def save_model(model, model_dir):
#     logger.info("Saving the model.")
#     path = os.path.join(model_dir, 'model.pth')
#     # recommended way from http://pytorch.org/docs/master/notes/serialization.html
#     torch.save(model.cpu().state_dict(), path)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#
#     # Data and model checkpoints directories
#     parser.add_argument('--batch-size', type=int, default=64, metavar='N',
#                         help='input batch size for training (default: 64)')
#     parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
#                         help='input batch size for testing (default: 1000)')
#     parser.add_argument('--epochs', type=int, default=10, metavar='N',
#                         help='number of epochs to train (default: 10)')
#     parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
#                         help='learning rate (default: 0.01)')
#     parser.add_argument('--momentum', type=float, default=0.5, metavar='M',
#                         help='SGD momentum (default: 0.5)')
#     parser.add_argument('--seed', type=int, default=1, metavar='S',
#                         help='random seed (default: 1)')
#     parser.add_argument('--log-interval', type=int, default=100, metavar='N',
#                         help='how many batches to wait before logging training status')
#     parser.add_argument('--backend', type=str, default=None,
#                         help='backend for distributed training (tcp, gloo on cpu and gloo, nccl on gpu)')
#
#     # Container environment
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ['SM_HOSTS']))
#     parser.add_argument('--current-host', type=str, default=os.environ['SM_CURRENT_HOST'])
#     parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--data-dir', type=str, default=os.environ['SM_CHANNEL_TRAINING'])
#     parser.add_argument('--num-gpus', type=int, default=os.environ['SM_NUM_GPUS'])
#
#     train(parser.parse_args())

# %% [markdown]
# ## 유용한 라이브러리

# %%
import pygments

# %%
# !pygmentize mnist.py
# Out:
# import argparse
# import json
# import logging
# import os
# import sagemaker_containers
# import sys
# import torch
# import torch.distributed as dist
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# import torch.utils.data
# import torch.utils.data.distributed
# from torchvision import datasets, transforms
#
# logger = logging.getLogger(__name__)
# logger.setLevel(logging.DEBUG)
# logger.addHandler(logging.StreamHandler(sys.stdout))
#
#
# # Based on https://github.com/pytorch/examples/blob/master/mnist/main.py
# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
#         self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
#         self.conv2_drop = nn.Dropout2d()
#         self.fc1 = nn.Linear(320, 50)
#         self.fc2 = nn.Linear(50, 10)
#
#     def forward(self, x):
#         x = F.relu(F.max_pool2d(self.conv1(x), 2))
#         x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
#         x = x.view(-1, 320)
#         x = F.relu(self.fc1(x))
#         x = F.dropout(x, training=self.training)
#         x = self.fc2(x)
#         return F.log_softmax(x, dim=1)
#
#
# def _get_train_data_loader(batch_size, training_dir, is_distributed, **kwargs):
#     logger.info("Get train data loader")
#     dataset = datasets.MNIST(training_dir, train=True, transform=transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize((0.1307,), (0.3081,))
#     ]))
#     train_sampler = torch.utils.data.distributed.DistributedSampler(dataset) if is_distributed else None
#     return torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=train_sampler is None,
#                                        sampler=train_sampler, **kwargs)
#
#
# def _get_test_data_loader(test_batch_size, training_dir, **kwargs):
#     logger.info("Get test data loader")
#     return torch.utils.data.DataLoader(
#         datasets.MNIST(training_dir, train=False, transform=transforms.Compose([
#             transforms.ToTensor(),
#             transforms.Normalize((0.1307,), (0.3081,))
#         ])),
#         batch_size=test_batch_size, shuffle=True, **kwargs)
#
#
# def _average_gradients(model):
#     # Gradient averaging.
#     size = float(dist.get_world_size())
#     for param in model.parameters():
#         dist.all_reduce(param.grad.data, op=dist.reduce_op.SUM)
#         param.grad.data /= size
#
#
# def train(args):
#     is_distributed = len(args.hosts) > 1 and args.backend is not None
#     logger.debug("Distributed training - {}".format(is_distributed))
#     use_cuda = args.num_gpus > 0
#     logger.debug("Number of gpus available - {}".format(args.num_gpus))
#     kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
#     device = torch.device("cuda" if use_cuda else "cpu")
#
#     if is_distributed:
#         # Initialize the distributed environment.
#         world_size = len(args.hosts)
#         os.environ['WORLD_SIZE'] = str(world_size)
#         host_rank = args.hosts.index(args.current_host)
#         os.environ['RANK'] = str(host_rank)
#         dist.init_process_group(backend=args.backend, rank=host_rank, world_size=world_size)
#         logger.info('Initialized the distributed environment: \'{}\' backend on {} nodes. '.format(
#             args.backend, dist.get_world_size()) + 'Current host rank is {}. Number of gpus: {}'.format(
#             dist.get_rank(), args.num_gpus))
#
#     # set the seed for generating random numbers
#     torch.manual_seed(args.seed)
#     if use_cuda:
#         torch.cuda.manual_seed(args.seed)
#
#     train_loader = _get_train_data_loader(args.batch_size, args.data_dir, is_distributed, **kwargs)
#     test_loader = _get_test_data_loader(args.test_batch_size, args.data_dir, **kwargs)
#
#     logger.debug("Processes {}/{} ({:.0f}%) of train data".format(
#         len(train_loader.sampler), len(train_loader.dataset),
#         100. * len(train_loader.sampler) / len(train_loader.dataset)
#     ))
#
#     logger.debug("Processes {}/{} ({:.0f}%) of test data".format(
#         len(test_loader.sampler), len(test_loader.dataset),
#         100. * len(test_loader.sampler) / len(test_loader.dataset)
#     ))
#
#     model = Net().to(device)
#     if is_distributed and use_cuda:
#         # multi-machine multi-gpu case
#         model = torch.nn.parallel.DistributedDataParallel(model)
#     else:
#         # single-machine multi-gpu case or single-machine or multi-machine cpu case
#         model = torch.nn.DataParallel(model)
#
#     optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)
#
#     for epoch in range(1, args.epochs + 1):
#         model.train()
#         for batch_idx, (data, target) in enumerate(train_loader, 1):
#             data, target = data.to(device), target.to(device)
#             optimizer.zero_grad()
#             output = model(data)
#             loss = F.nll_loss(output, target)
#             loss.backward()
#             if is_distributed and not use_cuda:
#                 # average gradients manually for multi-machine cpu case only
#                 _average_gradients(model)
#             optimizer.step()
#             if batch_idx % args.log_interval == 0:
#                 logger.info('Train Epoch: {} [{}/{} ({:.0f}%)] Loss: {:.6f}'.format(
#                     epoch, batch_idx * len(data), len(train_loader.sampler),
#                     100. * batch_idx / len(train_loader), loss.item()))
#         test(model, test_loader, device)
#     save_model(model, args.model_dir)
#
#
# def test(model, test_loader, device):
#     model.eval()
#     test_loss = 0
#     correct = 0
#     with torch.no_grad():
#         for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
#             output = model(data)
#             test_loss += F.nll_loss(output, target, size_average=False).item()  # sum up batch loss
#             pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
#             correct += pred.eq(target.view_as(pred)).sum().item()
#
#     test_loss /= len(test_loader.dataset)
#     logger.info('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
#         test_loss, correct, len(test_loader.dataset),
#         100. * correct / len(test_loader.dataset)))
#
#
# def model_fn(model_dir):
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     model = torch.nn.DataParallel(Net())
#     with open(os.path.join(model_dir, 'model.pth'), 'rb') as f:
#         model.load_state_dict(torch.load(f))
#     return model.to(device)
#
#
# def save_model(model, model_dir):
#     logger.info("Saving the model.")
#     path = os.path.join(model_dir, 'model.pth')
#     # recommended way from http://pytorch.org/docs/master/notes/serialization.html
#     torch.save(model.cpu().state_dict(), path)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#
#     # Data and model checkpoints directories
#     parser.add_argument('--batch-size', type=int, default=64, metavar='N',
#                         help='input batch size for training (default: 64)')
#     parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
#                         help='input batch size for testing (default: 1000)')
#     parser.add_argument('--epochs', type=int, default=10, metavar='N',
#                         help='number of epochs to train (default: 10)')
#     parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
#                         help='learning rate (default: 0.01)')
#     parser.add_argument('--momentum', type=float, default=0.5, metavar='M',
#                         help='SGD momentum (default: 0.5)')
#     parser.add_argument('--seed', type=int, default=1, metavar='S',
#                         help='random seed (default: 1)')
#     parser.add_argument('--log-interval', type=int, default=100, metavar='N',
#                         help='how many batches to wait before logging training status')
#     parser.add_argument('--backend', type=str, default=None,
#                         help='backend for distributed training (tcp, gloo on cpu and gloo, nccl on gpu)')
#
#     # Container environment
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ['SM_HOSTS']))
#     parser.add_argument('--current-host', type=str, default=os.environ['SM_CURRENT_HOST'])
#     parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--data-dir', type=str, default=os.environ['SM_CHANNEL_TRAINING'])
#     parser.add_argument('--num-gpus', type=int, default=os.environ['SM_NUM_GPUS'])
#
#     train(parser.parse_args())

# %%
# !pip install pyathena
# Out:
# Collecting pyathena
#   Downloading PyAthena-1.11.2-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 684 kB/s eta 0:00:011
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyathena) (0.18.2)
# Collecting tenacity>=4.1.0
#   Downloading tenacity-6.2.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: botocore>=1.5.52 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyathena) (1.17.59)
# Requirement already satisfied: boto3>=1.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyathena) (1.14.59)
# Requirement already satisfied: six>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tenacity>=4.1.0->pyathena) (1.14.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->pyathena) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->pyathena) (2.8.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->pyathena) (0.9.4)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->pyathena) (1.25.8)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.4.4->pyathena) (0.3.3)
# Installing collected packages: tenacity, pyathena
# Successfully installed pyathena-1.11.2 tenacity-6.2.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import pyathena

# %%
import pandas as pd

conn = connect(s3_staging_dir='s3://',
               region_name='ap-northeast-2')

source_df = pd.read_sql("select * from "<DB>"."<TABLE>";", conn)

# %% [markdown]
# ## 기본 sagemaker/boto3 Import

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

# %%
role = get_execution_role()

# %%
role
# Out:
# 'arn:aws:iam::309967292218:role/service-role/AmazonSageMaker-ExecutionRole-20200622T133405'

# %% [markdown]
# ## git commit

# %% [markdown]
# ## communication with s3

# %%
# !cat "hello"
# Out:
# cat: hello: No such file or directory

# %%
bucket = 'cjai-raw-initial-s3'
prefix = 'test/dsc-workshop'

# %%
import boto3
s3_client = boto3.client('s3')

# Upload the file to S3
#s3_client.upload_file('hello.txt', bucket, '/'.join((prefix,'hello-remote.txt')))

# Download the file from S3
s3_client.download_file(bucket, '/'.join((prefix,'hello-remote.txt')),'hello2.txt')

# %%
s3 = boto3.resource('s3')

# Upload the file to S3
# meta
s3.meta.client.upload_file('hello.txt', 'mybucket', 'hello-remote.txt')
# High-level
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', train_file)).upload_file(f)

# Download the file to S3
s3.meta.client.download_file('mybucket', 'hello-remote.txt', 'hello2.txt')

# %% [raw]
# s3_r = boto3.resource('s3')
# s3_fs = boto3.client('s3fs')

# %%
# key searching

# %% [markdown]
# ## setup IAM role

# %%
iam = boto3.client('iam')

# %%
iam.get_role(RoleName = "AmazonSageMaker-ExecutionRole-20200622T133405")
# Out:
# {'Role': {'Path': '/service-role/',
#   'RoleName': 'AmazonSageMaker-ExecutionRole-20200622T133405',
#   'RoleId': 'AROAUQK35Q45BQ4SBVZDV',
#   'Arn': 'arn:aws:iam::309967292218:role/service-role/AmazonSageMaker-ExecutionRole-20200622T133405',
#   'CreateDate': datetime.datetime(2020, 6, 22, 4, 34, 35, tzinfo=tzlocal()),
#   'AssumeRolePolicyDocument': {'Version': '2012-10-17',
#    'Statement': [{'Effect': 'Allow',
#      'Principal': {'Service': 'sagemaker.amazonaws.com'},
#      'Action': 'sts:AssumeRole'}]},
#   'Description': 'SageMaker execution role created from the SageMaker AWS Management Console.',
#   'MaxSessionDuration': 3600,
#   'RoleLastUsed': {'LastUsedDate': datetime.datetime(2020, 10, 13, 4, 38, 33, tzinfo=tzlocal()),
#    'Region': 'ap-northeast-2'}},
#  'ResponseMetadata': {'RequestId': '6e00d3ae-6b00-4bf7-9230-991ce45ea9c1',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6e00d3ae-6b00-4bf7-9230-991ce45ea9c1',
#    'content-type': 'text/xml',
#    'content-length': '1136',
#    'date': 'Tue, 13 Oct 2020 05:22:28 GMT'},
#   'RetryAttempts': 0}}

# %%
iam.attach_role_policy()

# %% [markdown]
# ## 한글 표 만들기

# %%
# !sudo cp /home/ec2-user/SageMaker/AmazonSageMaker-cjai-repository/dsc-workshop/fonts/*.ttf /usr/share/fonts/
# !sudo fc-cache -f -v
# !rm /home/ec2-user/.cache/matplotlib -fr
# Out:
# /usr/share/fonts: caching, new cache contents: 4 fonts, 2 dirs
# /usr/share/fonts/default: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/default/Type1: caching, new cache contents: 35 fonts, 0 dirs
# /usr/share/fonts/dejavu: caching, new cache contents: 21 fonts, 0 dirs
# /usr/share/X11/fonts/Type1: caching, new cache contents: 13 fonts, 0 dirs
# /usr/share/X11/fonts/TTF: skipping, no such directory
# /usr/local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
path = '/usr/share/fonts/NanumGothic.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np
x = np.arange(-5, 5, 0.01)
y = np.sin(x)

# %%
plt.figure().add_subplot().set_title('한글 제목 테스트 Plot')
plt.plot(x, y)

# %% [markdown]
# # Main SageMaker Functionality

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

# %%
container_lr = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
container_xg = get_image_uri(boto3.Session().region_name, 'xgboost', '1.0-1')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %% [markdown]
# ## Getting Data Ready

# %% [markdown]
# - serialize and upload data to S3
# - protobuff or csv
# - today we will to with csv

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', header = None)

# specify columns extracted from wbdc.names
data.columns = ["id","diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean",
                "compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean",
                "radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se",
                "concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst",
                "perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst",
                "concave points_worst","symmetry_worst","fractal_dimension_worst"] 

# save the data
data.to_csv("data.csv", sep=',', index=False)

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# - train , validation, test split

# %%
rand_split = np.random.rand(len(data))
train_list = rand_split < 0.8
val_list = (rand_split >= 0.8) & (rand_split < 0.9)
test_list = rand_split >= 0.9

data_train = data[train_list]
data_val = data[val_list]
data_test = data[test_list]

# %% [markdown]
# - labeling , label first for the csv format

# %%
train_y = ((data_train.iloc[:,1] == 'M') +0).to_numpy();
train_X = data_train.iloc[:,2:].to_numpy();

val_y = ((data_val.iloc[:,1] == 'M') +0).to_numpy();
val_X = data_val.iloc[:,2:].to_numpy();

test_y = ((data_test.iloc[:,1] == 'M') +0).to_numpy();
test_X = data_test.iloc[:,2:].to_numpy();

# %%
#csv dataset for training
train_csv = np.concatenate([train_y.astype('int').reshape(-1,1),train_X],axis=1)

# %%
np.savetxt('train.csv',train_csv, delimiter=',')
#pd.to_csv()

# %%
import os

train_file = 'train.csv'
f = 'train.csv'
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', train_file)).upload_file(f)

# %% [markdown]
# ## Estimator & Fit

# %%
s3_input = sagemaker.inputs.s3_input('s3://cjai-raw-initial-s3/test/dsc-workshop/train/train.csv',content_type='text/csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)

# %%
import boto3
import sagemaker

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container_lr,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)

linear.set_hyperparameters(feature_dim=30,
                           predictor_type='binary_classifier',
                           mini_batch_size=200)

linear.fit({'train': s3_input})
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2020-10-13 07:49:22 Starting - Starting the training job...
# 2020-10-13 07:49:26 Starting - Launching requested ML instances......
# 2020-10-13 07:50:24 Starting - Preparing the instances for training......
# 2020-10-13 07:51:35 Downloading - Downloading input data...
# 2020-10-13 07:52:14 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/13/2020 07:52:18 INFO 140331006433088] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/13/2020 07:52:18 INFO 140331006433088] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'30', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [10/13/2020 07:52:18 INFO 140331006433088] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/13/2020 07:52:18 WARNING 140331006433088] Loggers have already been setup.
# Process 1 is a worker.
# [10/13/2020 07:52:18 INFO 140331006433088] Using default worker.
# [10/13/2020 07:52:18 INFO 140331006433088] Checkpoint loading and saving are disabled.
# [10/13/2020 07:52:19 INFO 140331006433088] Create Store: local
# [10/13/2020 07:52:19 INFO 140331006433088] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa1044dfd10>
# [10/13/2020 07:52:19 INFO 140331006433088] Scaling model computed with parameters:
#  {'stdev_weight':
# [3.5087440e+00 4.0634103e+00 2.4170774e+01 3.5656717e+02 1.3839899e-02
#  5.4107681e-02 8.1611924e-02 3.9482176e-02 2.7726736e-02 7.1343314e-03
#  2.8895217e-01 5.1322436e-01 2.0857961e+00 4.9433449e+01 3.0782579e-03
#  1.8467106e-02 3.0279562e-02 6.0805725e-03 8.5261175e-03 2.8218604e-03
#  4.8657265e+00 5.9274430e+00 3.3670712e+01 5.8713879e+02 2.2769118e-02
#  1.5984622e-01 2.0760706e-01 6.6374891e-02 6.4262845e-02 1.8523814e-02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [1.4275974e+01 1.9047800e+01 9.2959671e+01 6.6815601e+02 9.6550800e-02
#  1.0476887e-01 9.1071561e-02 5.0282739e-02 1.8217325e-01 6.2502123e-02
#  4.1216600e-01 1.1825042e+00 2.9011207e+00 4.1729256e+01 6.9729527e-03
#  2.5402214e-02 3.1813577e-02 1.1714537e-02 2.0508021e-02 3.7347283e-03
#  1.6503216e+01 2.5472576e+01 1.0875565e+02 9.0620874e+02 1.3258028e-01
#  2.5728458e-01 2.7862096e-01 1.1730363e-01 2.9302698e-01 8.3707497e-02]
# <NDArray 30 @cpu(0)>}
# [10/13/2020 07:52:19 INFO 140331006433088] nvidia-smi took: 0.0251760482788 secs to identify 0 gpus
# [10/13/2020 07:52:19 INFO 140331006433088] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Total Records Seen": {"count": 1, "max": 670, "sum": 670.0, "min": 670}, "Max Records Seen Between Resets": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1602575539.159944, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1602575539.159907}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5825443077087402, "sum": 0.5825443077087402, "min": 0.5825443077087402}}, "EndTime": 1602575539.253785, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1602575539.253727}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6635241317749023, "sum": 0.6635241317749023, "min": 0.6635241317749023}}, "EndTime": 1602575539.253858, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1602575539.253845}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7436884307861328, "sum": 0.7436884307861328, "min": 0.7436884307861328}}, "EndTime": 1602575539.253906, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1602575539

#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8358983230590821, "sum": 0.8358983230590821, "min": 0.8358983230590821}}, "EndTime": 1602575539.255544, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1602575539.255528}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8970745468139648, "sum": 0.8970745468139648, "min": 0.8970745468139648}}, "EndTime": 1602575539.255597, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1602575539.255581}
#
# [10/13/2020 07:52:19 INFO 140331006433088] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.582544307709
# [10/13/2020 07:52:19 INFO 140331006433088] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.414916114807
# [10/13/2020 07:52:19 INFO 140331006433088] Epoch 0: Loss improved. Updating best model
# [10/13/2020 07:52:19 INFO 140331006433088] Saving model for epoch: 0
# [10/13/2020 07:52:19 INFO 140331006433088] Saved checkpoint to "/tmp/tmpYuZNMT/mx-mod-0000.params"
# [10/13/2020 07:52:19 INFO 140331006433088] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 1140, "sum": 1140.0, "min": 1140}, "Max Records Seen Between Resets": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1602575539.266276, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1602575539.160165}
#
# [10/13/2020 07:52:19 INFO 140331006433088] #throughput_metric: host=algo-1, train throughput=4424.44081849 records/second
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5256343269348145, "sum": 0.5256343269348145, "min": 0.5256343269348145}}, "EndTime": 1602575539.344929, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.344867}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5953984642028809, "sum": 0.5953984642028809, "min": 0.5953984642028809}}, "EndTime": 1602575539.34501, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.344992}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6694248580932617, "sum": 0.6694248580932617, "min": 0.6694248580932617}}, "EndTime": 1602575539.345099, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345079}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5985745429992676, "sum": 0.5985745429992676, "min": 0.5985745429992676}}, "EndTime": 1602575539.345173, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345155}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2151082420349121, "sum": 0.2151082420349121, "min": 0.2151082420349121}}, "EndTime": 1602575539.345256, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345237}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.23283061981201172, "sum": 0.23283061981201172, "min": 0.23283061981201172}}, "EndTime": 1602575539.345319, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345301}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.21842446327209472, "sum": 0.21842446327209472, "min": 0.21842446327209472}}, "EndTime": 1602575539.345384, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345366}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17504482746124267, "sum": 0.17504482746124267, "min": 0.17504482746124267}}, "EndTime": 1602575539.345434, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345419}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6781245040893554, "sum": 0.6781245040893554, "min": 0.6781245040893554}}, "EndTime": 1602575539.345521, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345503}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5890197563171387, "sum": 0.5890197563171387, "min": 0.5890197563171387}}, "EndTime": 1602575539.345579, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345563}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5919633483886719, "sum": 0.5919633483886719, "min": 0.5919633483886719}}, "EndTime": 1602575539.345633, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345617}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6170786666870117, "sum": 0.6170786666870117, "min": 0.6170786666870117}}, "EndTime": 1602575539.345697, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.34568}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.21484660625457763, "sum": 0.21484660625457763, "min": 0.21484660625457763}}, "EndTime": 1602575539.345757, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345741}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1860030174255371, "sum": 0.1860030174255371, "min": 0.1860030174255371}}, "EndTime": 1602575539.34583, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345813}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.21640005111694335, "sum": 0.21640005111694335, "min": 0.21640005111694335}}, "EndTime": 1602575539.345897, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.34588}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.21940069675445556, "sum": 0.21940069675445556, "min": 0.21940069675445556}}, "EndTime": 1602575539.345956, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345939}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.509167137145996, "sum": 0.509167137145996, "min": 0.509167137145996}}, "EndTime": 1602575539.346016, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.345999}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6383449172973633, "sum": 0.6383449172973633, "min": 0.6383449172973633}}, "EndTime": 1602575539.346092, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346059}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5977099800109863, "sum": 0.5977099800109863, "min": 0.5977099800109863}}, "EndTime": 1602575539.346155, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346138}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6469475555419922, "sum": 0.6469475555419922, "min": 0.6469475555419922}}, "EndTime": 1602575539.346217, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346199}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20093135833740233, "sum": 0.20093135833740233, "min": 0.20093135833740233}}, "EndTime": 1602575539.346274, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346257}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20833251476287842, "sum": 0.20833251476287842, "min": 0.20833251476287842}}, "EndTime": 1602575539.346321, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346306}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20421168327331543, "sum": 0.20421168327331543, "min": 0.20421168327331543}}, "EndTime": 1602575539.3464, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346382}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20741312503814696, "sum": 0.20741312503814696, "min": 0.20741312503814696}}, "EndTime": 1602575539.346467, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346451}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7151557540893555, "sum": 0.7151557540893555, "min": 0.7151557540893555}}, "EndTime": 1602575539.346525, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346509}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7447165298461914, "sum": 0.7447165298461914, "min": 0.7447165298461914}}, "EndTime": 1602575539.346579, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346563}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5928603363037109, "sum": 0.5928603363037109, "min": 0.5928603363037109}}, "EndTime": 1602575539.346637, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346619}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6700091552734375, "sum": 0.6700091552734375, "min": 0.6700091552734375}}, "EndTime": 1602575539.346724, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346705}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6182249641418457, "sum": 0.6182249641418457, "min": 0.6182249641418457}}, "EndTime": 1602575539.346783, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346767}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6737689208984375, "sum": 0.6737689208984375, "min": 0.6737689208984375}}, "EndTime": 1602575539.346845, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346828}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6207226943969727, "sum": 0.6207226943969727, "min": 0.6207226943969727}}, "EndTime": 1602575539.34693, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346887}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6379928779602051, "sum": 0.6379928779602051, "min": 0.6379928779602051}}, "EndTime": 1602575539.346995, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.346976}
#
# [10/13/2020 07:52:19 INFO 140331006433088] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.525634326935
# [10/13/2020 07:52:19 INFO 140331006433088] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.175044827461
# [10/13/2020 07:52:19 INFO 140331006433088] Epoch 1: Loss improved. Updating best model
# [10/13/2020 07:52:19 INFO 140331006433088] Saving model for epoch: 1
# [10/13/2020 07:52:19 INFO 140331006433088] Saved checkpoint to "/tmp/tmpxMknOj/mx-mod-0000.params"
# [10/13/2020 07:52:19 INFO 140331006433088] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Total Batches Seen": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Total Records Seen": {"count": 1, "max": 1610, "sum": 1610.0, "min": 1610}, "Max Records Seen Between Resets": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1602575539.354371, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1602575539.266551}
#
# [10/13/2020 07:52:19 INFO 140331006433088] #throughput_metric: host=algo-1, train throughput=5344.55446296 records/second
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.47685344696044923, "sum": 0.47685344696044923, "min": 0.47685344696044923}}, "EndTime": 1602575539.422556, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1602575539.4225}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5363676643371582, "sum": 0.5363676643371582, "min": 0.5363676643371582}}, "EndTime": 1602575539.422625, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1602575539.422613}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6038313484191895, "sum": 0.6038313484191895, "min": 0.6038313484191895}}, "EndTime": 1602575539.422694, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1602575539.422676}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.

#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.751439208984375, "sum": 0.751439208984375, "min": 0.751439208984375}}, "EndTime": 1602575539.424346, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1602575539.424329}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6344434356689453, "sum": 0.6344434356689453, "min": 0.6344434356689453}}, "EndTime": 1602575539.424413, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1602575539.424395}
#
# [10/13/2020 07:52:19 INFO 140331006433088] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.47685344696
# [10/13/2020 07:52:19 INFO 140331006433088] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.120708756447
# [10/13/2020 07:52:19 INFO 140331006433088] Epoch 2: Loss improved. Updating best model
# [10/13/2020 07:52:19 INFO 140331006433088] Saving model for epoch: 2
# [10/13/2020 07:52:19 INFO 140331006433088] Saved checkpoint to "/tmp/tmpjzmX3n/mx-mod-0000.params"
# [10/13/2020 07:52:19 INFO 140331006433088] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Total Batches Seen": {"count": 1, "max": 13, "sum": 13.0, "min": 13}, "Total Records Seen": {"count": 1, "max": 2080, "sum": 2080.0, "min": 2080}, "Max Records Seen Between Resets": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1602575539.432494, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1602575539.354626}
#
# [10/13/2020 07:52:19 INFO 140331006433088] #throughput_metric: host=algo-1, train throughput=6025.48837892 records/second
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.43531503677368166, "sum": 0.43531503677368166, "min": 0.43531503677368166}}, "EndTime": 1602575539.533591, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.533498}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.48615083694458006, "sum": 0.48615083694458006, "min": 0.48615083694458006}}, "EndTime": 1602575539.5337, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.533679}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5470241737365723, "sum": 0.5470241737365723, "min": 0.5470241737365723}}, "EndTime": 1602575539.533769, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.533751}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.49239402770996094, "sum": 0.49239402770996094, "min": 0.49239402770996094}}, "EndTime": 1602575539.533835, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.533818}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1482941484451294, "sum": 0.1482941484451294, "min": 0.1482941484451294}}, "EndTime": 1602575539.533897, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.533879}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16341403484344483, "sum": 0.16341403484344483, "min": 0.16341403484344483}}, "EndTime": 1602575539.533965, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.533949}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.10645976543426514, "sum": 0.10645976543426514, "min": 0.10645976543426514}}, "EndTime": 1602575539.534027, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.53401}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.09592814922332764, "sum": 0.09592814922332764, "min": 0.09592814922332764}}, "EndTime": 1602575539.534097, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.534079}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5560402870178223, "sum": 0.5560402870178223, "min": 0.5560402870178223}}, "EndTime": 1602575539.534158, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1602575539.534141}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2500770568847656, "sum": 0.2500770568847656, "min": 0.2500770568847656}}, "EndTime": 1602575540.445597, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.445573}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2742030334472656, "sum": 0.2742030334472656, "min": 0.2742030334472656}}, "EndTime": 1602575540.445666, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.445649}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.25215605735778807, "sum": 0.25215605735778807, "min": 0.25215605735778807}}, "EndTime": 1602575540.445726, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.44571}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.07522239208221436, "sum": 0.07522239208221436, "min": 0.07522239208221436}}, "EndTime": 1602575540.445788, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.44577}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.07845602989196777, "sum": 0.07845602989196777, "min": 0.07845602989196777}}, "EndTime": 1602575540.445849, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.445832}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.07258595705032349, "sum": 0.07258595705032349, "min": 0.07258595705032349}}, "EndTime": 1602575540.44591, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.445892}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.07162336111068726, "sum": 0.07162336111068726, "min": 0.07162336111068726}}, "EndTime": 1602575540.445968, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.445952}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0
#progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Total Batches Seen": {"count": 1, "max": 49, "sum": 49.0, "min": 49}, "Total Records Seen": {"count": 1, "max": 7720, "sum": 7720.0, "min": 7720}, "Max Records Seen Between Resets": {"count": 1, "max": 470, "sum": 470.0, "min": 470}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1602575540.455776, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1602575540.357786}
#
# [10/13/2020 07:52:20 INFO 140331006433088] #throughput_metric: host=algo-1, train throughput=4790.92735801 records/second
# [10/13/2020 07:52:20 WARNING 140331006433088] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/13/2020 07:52:20 WARNING 140331006433088] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/13/2020 07:52:20 INFO 140331006433088] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.07151850639505589)
# [10/13/2020 07:52:20 INFO 140331006433088] #train_score (algo-1) : ('binary_classification_accuracy', 0.9787234042553191)
# [10/13/2020 07:52:20 INFO 140331006433088] #train_score (algo-1) : ('binary_f_1.000', 0.9712643678160919)
# [10/13/2020 07:52:20 INFO 140331006433088] #train_score (algo-1) : ('precision', 0.9825581395348837)
# [10/13/2020 07:52:20 INFO 140331006433088] #train_score (algo-1) : ('recall', 0.9602272727272727)
# [10/13/2020 07:52:20 INFO 140331006433088] #train_score (algo-1) : ('roc_auc_score', 0.9950718923933208)
# [10/13/2020 07:52:20 INFO 140331006433088] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.0715185063951
# [10/13/2020 07:52:20 INFO 140331006433088] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.978723404255
# [10/13/2020 07:52:20 INFO 140331006433088] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.971264367816
# [10/13/2020 07:52:20 INFO 140331006433088] #quality_metric: host=algo-1, train precision <score>=0.982558139535
# [10/13/2020 07:52:20 INFO 140331006433088] #quality_metric: host=algo-1, train recall <score>=0.960227272727
# [10/13/2020 07:52:20 INFO 140331006433088] #quality_metric: host=algo-1, train roc_auc_score <score>=0.995071892393
# [10/13/2020 07:52:20 INFO 140331006433088] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [10/13/2020 07:52:20 INFO 140331006433088] Saved checkpoint to "/tmp/tmpkXWfAj/mx-mod-0000.params"
# [10/13/2020 07:52:20 INFO 140331006433088] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1960.7670307159424, "sum": 1960.7670307159424, "min": 1960.7670307159424}, "finalize.time": {"count": 1, "max": 174.4229793548584, "sum": 174.4229793548584, "min": 174.4229793548584}, "initialize.time": {"count": 1, "max": 160.57419776916504, "sum": 160.57419776916504, "min": 160.57419776916504}, "check_early_stopping.time": {"count": 15, "max": 1.1529922485351562, "sum": 12.158393859863281, "min": 0.7140636444091797}, "setuptime": {"count": 1, "max": 29.274940490722656, "sum": 29.274940490722656, "min": 29.274940490722656}, "update.time": {"count": 15, "max": 109.74812507629395, "sum": 1250.5927085876465, "min": 64.1031265258789}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1602575540.635945, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1602575538.999123}
# 2020-10-13 07:52:32 Uploading - Uploading generated training model
# 2020-10-13 07:52:32 Completed - Training job completed
# Training seconds: 57
# Billable seconds: 57

# %% [markdown]
# ## Deploy

# %%
linear.deploy('ml.m4.xlarge','test-endpoint')

# %% [markdown]
# ## Predict

# %%
linear.predictor()

# %%
linear.delete_endpoint()
